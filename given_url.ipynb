# %%
import re
import requests
import pandas
import matplotlib

# %%
f = open('bbs_urls.txt')
urls = f.read()
urls = urls.split('\n')
f.close()

# %%
s = requests.Session()
headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/57.0.2987.133 Safari/537.36'
}

for url in urls:
    try:
        r = s.get(url, headers = headers, timeout = 2)
        print(r, r.url)
    except (requests.exceptions.ReadTimeout, requests.exceptions.ConnectionError, requests.exceptions.ConnectTimeout):
        print('read time out:', r.url)
# Out:
# <Response [200]> http://36.01ny.cn/thread-4552447-1-1.html
# <Response [200]> http://36.01ny.cn/thread-4575240-1-1.html
# <Response [200]> http://36.01ny.cn/thread-4590191-1-1.html
# <Response [200]> http://8.7k7k.com/thread-1453189-1-1.html
# <Response [200]> http://baa.bitauto.com/changancs75/thread-9819102.html
# <Response [200]> http://bbs.360.cn/thread-14503855-1-1.html
# <Response [200]> http://bbs.360.cn/thread-14593261-1-1.html
# <Response [200]> http://bbs.360.cn/thread-14651322-1-1.html
# <Response [200]> http://bbs.360.cn/thread-14659761-1-1.html
# <Response [200]> http://bbs.360.cn/thread-14671216-1-1.html
# <Response [200]> http://bbs.52waha.com/thread-296146-5-1.html
# <Response [200]> http://bbs.52waha.com/thread-389728-1-1.html
# <Response [200]> http://bbs.55bbs.com/thread-10035673-1-1.html
# <Response [200]> http://bbs.9game.cn/thread-20674778-1-1.html
# <Response [200]> http://bbs.9game.cn/thread-21014570-1-1.html
# <Response [200]> http://bbs.auto.ifeng.com/thread-2699751-1-1.html
# <Response [200]> http://bbs.auto.ifeng.com/thread-2774095-1-1.html
# <Response [200]> http://bbs.cheshi.com/thread-5000217-1-1.html
# <Response [200]> http://bbs.chetxia.com/127/35_20946355_20946355.htm
# <Response [200]> http://bbs.chetxia.com/256/367_22924508_22924508.htm
# <Response [200]> http://bbs.chetxia.com/472/963_23015930_23015930.htm
# <Response [200]> http://bbs.ci123.com/post/80673774.html/0
# <Response [200]> http://bbs.ci123.com/post/80673774.html/45
# <Response [200]> http://bbs.cnnb.com.cn/forum.php?mod=viewthread&tid=7267273&extra=page%3D1
# <Response [200]> http://bbs.coolpad.com/thread-5147419-1-1.html
# <Response [404]> http://bbs.dospy.com/thread-17495473-1-784-1.html
# <Response [200]> http://bbs.dospy.com/thread-17533651-1-707-1.html
# <Response [200]> http://bbs.dospy.com/thread-17655769-1-1001-1.html
# <Response [200]> http://bbs.dospy.com/thread-17764137-1-141-1.html
# <Response [200]> http://bbs.duowan.com/thread-44650287-1-1.html
# <Response [200]> http://bbs.duowan.com/thread-45199277-1-1.html
# <Response [200]> http://bbs.e23.cn/thread-180133942-1-1.html
# <Response [200]> http://bbs.e23.cn/thread-180138165-1-1.html
# <Response [200]> http://bbs.e23.cn/thread-180195587-1-1.html
# <Response [404]> http://bbs.eastmoney.com/dispbbs.asp?boardID=3&ID=5151913
# <Response [200]> http://bbs.elecfans.com/jishu_569610_1_1.html
# read time out: http://bbs.elecfans.com/jishu_569610_1_1.html
# read time out: http://bbs.elecfans.com/jishu_569610_1_1.html
# <Response [200]> http://ent.qq.com
# <Response [200]> http://bbs.feng.com/read-htm-tid-10884382.html
# <Response [200]> http://bbs.gfan.com/android-8397839-1-1.html
# <Response [200]> http://bbs.gfan.com/android-8401455-1-1.html
# <Response [200]> http://bbs.guanjia.qq.com/forum.php?mod=viewthread&tid=5000457&extra=page%3D1
# <Response [200]> http://guba.sina.com.cn/?s=thread&tid=500237&bid=1
# <Response [200]> http://guba.sina.com.cn/?s=thread&tid=742&bid=16396
# <Response [200]> http://hongdou.gxnews.com.cn/viewthread-14711356.html
# <Response [200]> http://ibbs.91.com/thread-3332770-1-1.html
# <Response [200]> http://itbbs.pconline.com.cn/dc/52686220.html
# <Response [200]> http://itbbs.pconline.com.cn/dc/53185264.html
# <Response [200]> http://itbbs.pconline.com.cn/mobile/53155576.html
# <Response [200]> http://itbbs.pconline.com.cn/office/53223667.html
# <Response [200]> http://mygd.qq.com/t-1760656-1.htm
# <Response [200]> http://mygd.qq.com/t-1825527-1.htm
# <Response [200]> http://nanhai.hinews.cn/thread-7061634-1-1.html
# <Response [200]> http://s.dianping.com/topic/14041909
# <Response [200]> http://s.dianping.com/topic/14443475
# <Response [200]> http://sxy.hc360.com/article-170598.html
# <Response [200]> http://www.099t.com/read.php?tid=725144
# <Response [200]> http://www.17lu.cn/read-htm-tid-2355032.html
# <Response [200]> http://www.3sogou.com/read.php?tid=1089011
# <Response [200]> http://www.55188.com/thread-7726322-1-1.html
# <Response [200]> http://www.55188.com/thread-7759353-1-1.html
# read time out: http://www.55188.com/thread-7759353-1-1.html
# read time out: http://www.55188.com/thread-7759353-1-1.html
# <Response [200]> http://www.dddzs.com/read.php?tid=1370668
# <Response [200]> http://www.dddzs.com/read.php?tid=1391902&page=e
# <Response [200]> http://www.ecuer.com/read.php?tid=755388
# <Response [200]> http://www.hainei.org/thread-6460959-1-1.html
# <Response [200]> http://www.hainei.org/thread-6570429-1-1.html
# <Response [200]> http://www.hhphh.com/read.php?tid=957741
# <Response [200]> http://www.lookgz.com/thread-1060172-1-1.html
# <Response [200]> http://www.lookgz.com/thread-1091960-1-1.html
# <Response [200]> http://www.oneplusbbs.com/thread-2959968-1-1.html
# <Response [200]> http://www.oneplusbbs.com/thread-3046354-1-1.html
# <Response [200]> http://www.pengfu.com/content_1593692_1.html
# <Response [200]> http://www.shdxlt.cn/ShowPost.asp?ThreadID=144952
# <Response [200]> http://sisiww.com
# <Response [200]> http://www.szbbs.cn/thread-2898054-1-1.html
# <Response [200]> http://www.xcar.com.cn/bbs/viewthread.php?tid=17791218
# <Response [200]> http://www.xcar.com.cn/404.htm
# <Response [200]> http://www.xici.net/d235376120.htm
# <Response [200]> http://x.heshuicun.com/thread-426-2-1.html
# <Response [200]> http://x.heshuicun.com/thread-65127-1-1.html
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# <ipython-input-11-1dafb8a61dc2> in <module>()
#       6 for url in urls:
#       7     try:
# ----> 8         r = s.get(url, headers = headers, timeout = 2)
#       9         print(r, r.url)
#      10     except (requests.exceptions.ReadTimeout, requests.exceptions.ConnectionError, requests.exceptions.ConnectTimeout):
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/requests/sessions.py in get(self, url, **kwargs)
#     486
#     487         kwargs.setdefault('allow_redirects', True)
# --> 488         return self.request('GET', url, **kwargs)
#     489
#     490     def options(self, url, **kwargs):
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     459             hooks = hooks,
#     460         )
# --> 461         prep = self.prepare_request(req)
#     462
#     463         proxies = proxies or {}
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/requests/sessions.py in prepare_request(self, request)
#     392             auth=merge_setting(auth, self.auth),
#     393             cookies=merged_cookies,
# --> 394             hooks=merge_hooks(request.hooks, self.hooks),
#     395         )
#     396         return p
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/requests/models.py in prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     292
#     293         self.prepare_method(method)
# --> 294         self.prepare_url(url, params)
#     295         self.prepare_headers(headers)
#     296         self.prepare_cookies(cookies)
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/requests/models.py in prepare_url(self, url, params)
#     352             error = error.format(to_native_string(url, 'utf8'))
#     353
# --> 354             raise MissingSchema(error)
#     355
#     356         if not host:
#
# MissingSchema: Invalid URL '': No schema supplied. Perhaps you meant http://?
